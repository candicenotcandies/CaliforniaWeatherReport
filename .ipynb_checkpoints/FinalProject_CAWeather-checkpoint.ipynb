# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv("2020daily193.csv")

# %%
caw_df=pd.DataFrame(df)

# %%
df_compare=pd.read_csv("2020daily091.csv")

# %%
caw_df_compare=pd.DataFrame(df_compare)

# %%
caw_df
# Out:
#      Station Id        Date  Julian Date  Reference ETo   (in)   (mm)  \
# 0           193    1/1/2020            1                         0.02
# 1           193    1/2/2020            2                         0.06
# 2           193    1/3/2020            3                         0.06
# 3           193    1/4/2020            4                         0.05
# 4           193    1/5/2020            5                         0.06
# ..          ...         ...          ...                          ...
# 361         193  12/27/2020          362                         0.06
# 362         193  12/28/2020          363                         0.05
# 363         193  12/29/2020          364                         0.06
# 364         193  12/30/2020          365                         0.05
# 365         193  12/31/2020          366                         0.06
#
#     QC for Reference ETo  Precipitation   (in)   (mm) QC for Precipitation  \
# 0                                                0.00
# 1                                                0.00
# 2                                                0.00
# 3                                                0.00
# 4                                                0.00
# ..                   ...                          ...                  ...
# 361                                              0.10
# 362                                              0.10
# 363                                              0.00
# 364                                              0.02
# 365                                              0.03
#
#      Solar Radiation Average   (Ly/day)   (W/m≤)  \
# 0                                            131
# 1                                            264
# 2                                            275
# 3                                            218
# 4                                            277
# ..                                           ...
# 361                                          252
# 362                                          219
# 363                                          274
# 364                                          259
# 365                                          262
#
#     QC for Solar Radiation Average  Average Vapor Pressure   (mBars)   (kPa)  \
# 0                                                                       13.4
# 1                                                                       12.8
# 2                                                                       11.0
# 3                                                                       12.8
# 4                                                                       11.0
# ..                             ...                                       ...
# 361                                                                     10.7
# 362                                                                     10.6
# 363                                                                      9.5
# 364                                                                      9.8
# 365                                                                     11.2
#
#      ... Average Relative Humidity   (%) QC for Average Relative Humidity  \
# 0    ...                              96
# 1    ...                              90
# 2    ...                              79
# 3    ...                              90
# 4    ...                              81
# ..   ...                             ...                              ...
# 361  ...                              86
# 362  ...                              85
# 363  ...                              80
# 364  ...                              86
# 365  ...                              86
#
#     Dew Point   (∞F)   (∞C) QC for Dew Point  \
# 0                      52.3
# 1                      51.1
# 2                        47
# 3                      51.2
# 4                      47.1
# ..                      ...              ...
# 361                    46.4
# 362                    46.2
# 363                    43.2
# 364                    44.1
# 365                    47.5
#
#     Average Wind Speed   (mph)   (m/s) QC for Average Wind Speed  \
# 0                                  7.2
# 1                                  4.8
# 2                                  3.6
# 3                                  5.8
# 4                                  6.9
# ..                                 ...                       ...
# 361                                2.6
# 362                                3.0
# 363                                1.9
# 364                                1.9
# 365                                3.9
#
#     Wind Run   (miles)   (km) QC for Wind Run  \
# 0                       173.1
# 1                       114.7
# 2                        85.4
# 3                       139.1
# 4                       164.6
# ..                        ...             ...
# 361                      62.5
# 362                      71.7
# 363                      46.2
# 364                      45.0
# 365                      94.3
#
#     Average Soil Temperature   (∞F)   (∞C) QC for Average Soil Temperature
# 0                                     55.6
# 1                                     56.2
# 2                                     56.0
# 3                                     56.3
# 4                                     56.4
# ..                                     ...                             ...
# 361                                   55.5
# 362                                   55.4
# 363                                   55.1
# 364                                   54.3
# 365                                   54.8
#
# [366 rows x 31 columns]

# %%
caw_df_compare
# Out:
#      Station Id        Date  Julian Date  Reference ETo   (in)   (mm)  \
# 0            91    1/1/2020            1                         0.03
# 1            91    1/2/2020            2                         0.04
# 2            91    1/3/2020            3                         0.05
# 3            91    1/4/2020            4                         0.04
# 4            91    1/5/2020            5                         0.03
# ..          ...         ...          ...                          ...
# 361          91  12/27/2020          362                         0.03
# 362          91  12/28/2020          363                         0.04
# 363          91  12/29/2020          364                         0.02
# 364          91  12/30/2020          365                         0.04
# 365          91  12/31/2020          366                         0.02
#
#     QC for Reference ETo  Precipitation   (in)   (mm) QC for Precipitation  \
# 0                                                0.08
# 1                                                0.00
# 2                                                0.00
# 3                                                0.08
# 4                                                0.00
# ..                   ...                          ...                  ...
# 361                                              0.00
# 362                                              0.00
# 363                                              0.00
# 364                                              0.00
# 365                                              0.20
#
#      Solar Radiation Average   (Ly/day)   (W/m≤)  \
# 0                                            130
# 1                                            184
# 2                                            145
# 3                                            174
# 4                                            139
# ..                                           ...
# 361                                          142
# 362                                          213
# 363                                          178
# 364                                          132
# 365                                          109
#
#     QC for Solar Radiation Average  Average Vapor Pressure   (mBars)   (kPa)  \
# 0                                                                        7.1
# 1                                                                        5.6
# 2                                                                        4.9
# 3                                                                        5.7
# 4                                                                        5.1
# ..                             ...                                       ...
# 361                                                                      4.2
# 362                                                                      3.6
# 363                                                                      3.4
# 364                                                                      4.7
# 365                                                                      4.4
#
#      ... Average Relative Humidity   (%)  QC for Average Relative Humidity  \
# 0    ...                              84
# 1    ...                              79
# 2    ...                              64
# 3    ...                              76
# 4    ...                              87
# ..   ...                             ...                               ...
# 361  ...                              79
# 362  ...                              69
# 363  ...                              82
# 364  ...                              70
# 365  ...                              85
#
#     Dew Point   (∞F)   (∞C)  QC for Dew Point  \
# 0                      35.6
# 1                      29.8
# 2                      26.5
# 3                      30.3
# 4                      27.7
# ..                      ...               ...
# 361                    23.0
# 362                    19.5
# 363                    18.1
# 364                    25.6
# 365                    24.1
#
#     Average Wind Speed   (mph)   (m/s)  QC for Average Wind Speed  \
# 0                                  7.7
# 1                                  3.3
# 2                                  5.4
# 3                                  6.2
# 4                                  4.4
# ..                                 ...                        ...
# 361                                3.5
# 362                                5.1
# 363                                1.8
# 364                                5.7
# 365                                2.3
#
#     Wind Run   (miles)   (km)  QC for Wind Run  \
# 0                       184.8
# 1                        79.2
# 2                       129.4
# 3                       149.0
# 4                       106.3
# ..                        ...              ...
# 361                      85.2
# 362                     121.7
# 363                      42.7
# 364                     135.8
# 365                      54.5
#
#     Average Soil Temperature   (∞F)   (∞C)  QC for Average Soil Temperature
# 0                                     36.1
# 1                                     36.8
# 2                                     36.5
# 3                                     36.9
# 4                                     37.4
# ..                                     ...                              ...
# 361                                   34.8
# 362                                   34.6
# 363                                   34.1
# 364                                   34.0
# 365                                   34.1
#
# [366 rows x 31 columns]
