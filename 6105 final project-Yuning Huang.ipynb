# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set(color_codes=True)

# %%
df=pd.read_csv("2020daily193.csv", index_col='Date',parse_dates=True)

# %%
caw_df=pd.DataFrame(df)

# %%
df_compare=pd.read_csv("2020daily091.csv",index_col='Date',parse_dates=True)

# %%
caw_df_compare=pd.DataFrame(df_compare)

# %%
caw_df
# Out:
#             Station Id  Julian Date  Reference ETo   (in)   (mm)  \
# Date
# 2020-01-01         193            1                         0.02
# 2020-01-02         193            2                         0.06
# 2020-01-03         193            3                         0.06
# 2020-01-04         193            4                         0.05
# 2020-01-05         193            5                         0.06
# ...                ...          ...                          ...
# 2020-12-27         193          362                         0.06
# 2020-12-28         193          363                         0.05
# 2020-12-29         193          364                         0.06
# 2020-12-30         193          365                         0.05
# 2020-12-31         193          366                         0.06
#
#            QC for Reference ETo  Precipitation   (in)   (mm)  \
# Date
# 2020-01-01                                              0.00
# 2020-01-02                                              0.00
# 2020-01-03                                              0.00
# 2020-01-04                                              0.00
# 2020-01-05                                              0.00
# ...                         ...                          ...
# 2020-12-27                                              0.10
# 2020-12-28                                              0.10
# 2020-12-29                                              0.00
# 2020-12-30                                              0.02
# 2020-12-31                                              0.03
#
#            QC for Precipitation  Solar Radiation Average   (Ly/day)   (W/m≤)  \
# Date
# 2020-01-01                                                               131
# 2020-01-02                                                               264
# 2020-01-03                                                               275
# 2020-01-04                                                               218
# 2020-01-05                                                               277
# ...                         ...                                          ...
# 2020-12-27                                                               252
# 2020-12-28                                                               219
# 2020-12-29                                                               274
# 2020-12-30                                                               259
# 2020-12-31                                                               262
#
#            QC for Solar Radiation Average  \
# Date
# 2020-01-01
# 2020-01-02
# 2020-01-03
# 2020-01-04
# 2020-01-05
# ...                                   ...
# 2020-12-27
# 2020-12-28
# 2020-12-29
# 2020-12-30
# 2020-12-31
#
#             Average Vapor Pressure   (mBars)   (kPa)  \
# Date
# 2020-01-01                                      13.4
# 2020-01-02                                      12.8
# 2020-01-03                                      11.0
# 2020-01-04                                      12.8
# 2020-01-05                                      11.0
# ...                                              ...
# 2020-12-27                                      10.7
# 2020-12-28                                      10.6
# 2020-12-29                                       9.5
# 2020-12-30                                       9.8
# 2020-12-31                                      11.2
#
#            QC for Average Vapor Pressure   ...  \
# Date                                       ...
# 2020-01-01                                 ...
# 2020-01-02                                 ...
# 2020-01-03                                 ...
# 2020-01-04                                 ...
# 2020-01-05                                 ...
# ...                                   ...  ...
# 2020-12-27                                 ...
# 2020-12-28                                 ...
# 2020-12-29                                 ...
# 2020-12-30                                 ...
# 2020-12-31                                 ...
#
#            Average Relative Humidity   (%) QC for Average Relative Humidity  \
# Date
# 2020-01-01                              96
# 2020-01-02                              90
# 2020-01-03                              79
# 2020-01-04                              90
# 2020-01-05                              81
# ...                                    ...                              ...
# 2020-12-27                              86
# 2020-12-28                              85
# 2020-12-29                              80
# 2020-12-30                              86
# 2020-12-31                              86
#
#            Dew Point   (∞F)   (∞C) QC for Dew Point  \
# Date
# 2020-01-01                    52.3
# 2020-01-02                    51.1
# 2020-01-03                      47
# 2020-01-04                    51.2
# 2020-01-05                    47.1
# ...                            ...              ...
# 2020-12-27                    46.4
# 2020-12-28                    46.2
# 2020-12-29                    43.2
# 2020-12-30                    44.1
# 2020-12-31                    47.5
#
#            Average Wind Speed   (mph)   (m/s) QC for Average Wind Speed  \
# Date
# 2020-01-01                                7.2
# 2020-01-02                                4.8
# 2020-01-03                                3.6
# 2020-01-04                                5.8
# 2020-01-05                                6.9
# ...                                       ...                       ...
# 2020-12-27                                2.6
# 2020-12-28                                3.0
# 2020-12-29                                1.9
# 2020-12-30                                1.9
# 2020-12-31                                3.9
#
#            Wind Run   (miles)   (km) QC for Wind Run  \
# Date
# 2020-01-01                     173.1
# 2020-01-02                     114.7
# 2020-01-03                      85.4
# 2020-01-04                     139.1
# 2020-01-05                     164.6
# ...                              ...             ...
# 2020-12-27                      62.5
# 2020-12-28                      71.7
# 2020-12-29                      46.2
# 2020-12-30                      45.0
# 2020-12-31                      94.3
#
#            Average Soil Temperature   (∞F)   (∞C)  \
# Date
# 2020-01-01                                   55.6
# 2020-01-02                                   56.2
# 2020-01-03                                   56.0
# 2020-01-04                                   56.3
# 2020-01-05                                   56.4
# ...                                           ...
# 2020-12-27                                   55.5
# 2020-12-28                                   55.4
# 2020-12-29                                   55.1
# 2020-12-30                                   54.3
# 2020-12-31                                   54.8
#
#            QC for Average Soil Temperature
# Date
# 2020-01-01
# 2020-01-02
# 2020-01-03
# 2020-01-04
# 2020-01-05
# ...                                    ...
# 2020-12-27
# 2020-12-28
# 2020-12-29
# 2020-12-30
# 2020-12-31
#
# [366 rows x 30 columns]

# %%
caw_df_compare
# Out:
#             Station Id  Julian Date  Reference ETo   (in)   (mm)  \
# Date
# 2020-01-01          91            1                         0.03
# 2020-01-02          91            2                         0.04
# 2020-01-03          91            3                         0.05
# 2020-01-04          91            4                         0.04
# 2020-01-05          91            5                         0.03
# ...                ...          ...                          ...
# 2020-12-27          91          362                         0.03
# 2020-12-28          91          363                         0.04
# 2020-12-29          91          364                         0.02
# 2020-12-30          91          365                         0.04
# 2020-12-31          91          366                         0.02
#
#            QC for Reference ETo  Precipitation   (in)   (mm)  \
# Date
# 2020-01-01                                              0.08
# 2020-01-02                                              0.00
# 2020-01-03                                              0.00
# 2020-01-04                                              0.08
# 2020-01-05                                              0.00
# ...                         ...                          ...
# 2020-12-27                                              0.00
# 2020-12-28                                              0.00
# 2020-12-29                                              0.00
# 2020-12-30                                              0.00
# 2020-12-31                                              0.20
#
#            QC for Precipitation  Solar Radiation Average   (Ly/day)   (W/m≤)  \
# Date
# 2020-01-01                                                               130
# 2020-01-02                                                               184
# 2020-01-03                                                               145
# 2020-01-04                                                               174
# 2020-01-05                                                               139
# ...                         ...                                          ...
# 2020-12-27                                                               142
# 2020-12-28                                                               213
# 2020-12-29                                                               178
# 2020-12-30                                                               132
# 2020-12-31                                                               109
#
#            QC for Solar Radiation Average  \
# Date
# 2020-01-01
# 2020-01-02
# 2020-01-03
# 2020-01-04
# 2020-01-05
# ...                                   ...
# 2020-12-27
# 2020-12-28
# 2020-12-29
# 2020-12-30
# 2020-12-31
#
#             Average Vapor Pressure   (mBars)   (kPa)  \
# Date
# 2020-01-01                                       7.1
# 2020-01-02                                       5.6
# 2020-01-03                                       4.9
# 2020-01-04                                       5.7
# 2020-01-05                                       5.1
# ...                                              ...
# 2020-12-27                                       4.2
# 2020-12-28                                       3.6
# 2020-12-29                                       3.4
# 2020-12-30                                       4.7
# 2020-12-31                                       4.4
#
#            QC for Average Vapor Pressure   ...  \
# Date                                       ...
# 2020-01-01                                 ...
# 2020-01-02                                 ...
# 2020-01-03                                 ...
# 2020-01-04                                 ...
# 2020-01-05                                 ...
# ...                                   ...  ...
# 2020-12-27                                 ...
# 2020-12-28                                 ...
# 2020-12-29                                 ...
# 2020-12-30                                 ...
# 2020-12-31                                 ...
#
#             Average Relative Humidity   (%) QC for Average Relative Humidity  \
# Date
# 2020-01-01                               84
# 2020-01-02                               79
# 2020-01-03                               64
# 2020-01-04                               76
# 2020-01-05                               87
# ...                                     ...                              ...
# 2020-12-27                               79
# 2020-12-28                               69
# 2020-12-29                               82
# 2020-12-30                               70
# 2020-12-31                               85
#
#             Dew Point   (∞F)   (∞C) QC for Dew Point  \
# Date
# 2020-01-01                     35.6
# 2020-01-02                     29.8
# 2020-01-03                     26.5
# 2020-01-04                     30.3
# 2020-01-05                     27.7
# ...                             ...              ...
# 2020-12-27                     23.0
# 2020-12-28                     19.5
# 2020-12-29                     18.1
# 2020-12-30                     25.6
# 2020-12-31                     24.1
#
#             Average Wind Speed   (mph)   (m/s) QC for Average Wind Speed  \
# Date
# 2020-01-01                                 7.7
# 2020-01-02                                 3.3
# 2020-01-03                                 5.4
# 2020-01-04                                 6.2
# 2020-01-05                                 4.4
# ...                                        ...                       ...
# 2020-12-27                                 3.5
# 2020-12-28                                 5.1
# 2020-12-29                                 1.8
# 2020-12-30                                 5.7
# 2020-12-31                                 2.3
#
#             Wind Run   (miles)   (km) QC for Wind Run  \
# Date
# 2020-01-01                      184.8
# 2020-01-02                       79.2
# 2020-01-03                      129.4
# 2020-01-04                      149.0
# 2020-01-05                      106.3
# ...                               ...             ...
# 2020-12-27                       85.2
# 2020-12-28                      121.7
# 2020-12-29                       42.7
# 2020-12-30                      135.8
# 2020-12-31                       54.5
#
#             Average Soil Temperature   (∞F)   (∞C)  \
# Date
# 2020-01-01                                    36.1
# 2020-01-02                                    36.8
# 2020-01-03                                    36.5
# 2020-01-04                                    36.9
# 2020-01-05                                    37.4
# ...                                            ...
# 2020-12-27                                    34.8
# 2020-12-28                                    34.6
# 2020-12-29                                    34.1
# 2020-12-30                                    34.0
# 2020-12-31                                    34.1
#
#            QC for Average Soil Temperature
# Date
# 2020-01-01
# 2020-01-02
# 2020-01-03
# 2020-01-04
# 2020-01-05
# ...                                    ...
# 2020-12-27
# 2020-12-28
# 2020-12-29
# 2020-12-30
# 2020-12-31
#
# [366 rows x 30 columns]

# %% [markdown]
# ---

# %% [markdown]
# Compare the Average Vapor Pressure of the two places.
#
# Vapor Pressure definition: It is the amount of pressure in millibars exerted by the water vapor in the air.
#
# It is natural to make the assumption that the Average Vapor Pressure of Pacific Grove is higher than that of Coalinga since Pacific Grove is a coastal city while Coalinga is located in California's central valley.

# %%
#  Average Vapor Pressure of Pacific Grove 
caw_vapor = caw_df.iloc[:,[8]]
caw_vapor
# Out:
#             Average Vapor Pressure   (mBars)   (kPa)
# Date
# 2020-01-01                                      13.4
# 2020-01-02                                      12.8
# 2020-01-03                                      11.0
# 2020-01-04                                      12.8
# 2020-01-05                                      11.0
# ...                                              ...
# 2020-12-27                                      10.7
# 2020-12-28                                      10.6
# 2020-12-29                                       9.5
# 2020-12-30                                       9.8
# 2020-12-31                                      11.2
#
# [366 rows x 1 columns]

# %%
print(type(caw_vapor.index))
# Out:
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>

# %%
# Monthly and quarterly sum of Average Vapor Pressure, Pacific Grove
print("Monthly Average Vapor Pressure, Pacific Grove")
print()
caw_vapor_monthly_average = caw_vapor.resample('M').mean()
print(caw_vapor_monthly_average)
print('-----------------------------------------------------')
print("Quarterly Average Vapor Pressure, Pacific Grove")
caw_vapor_quarter_average = caw_vapor.resample('Q').mean()/3
print()
print(caw_vapor.resample('Q').mean()/3)
# Out:
# Monthly Average Vapor Pressure, Pacific Grove
#
#             Average Vapor Pressure   (mBars)   (kPa)
# Date
# 2020-01-31                                 11.506452
# 2020-02-29                                 10.434483
# 2020-03-31                                 11.100000
# 2020-04-30                                 12.366667
# 2020-05-31                                 13.883871
# 2020-06-30                                 14.456667
# 2020-07-31                                 14.896774
# 2020-08-31                                 16.080645
# 2020-09-30                                 16.083333
# 2020-10-31                                 14.777419
# 2020-11-30                                 10.923333
# 2020-12-31                                 10.167742
# -----------------------------------------------------
# Quarterly Average Vapor Pressure, Pacific Grove
#
#             Average Vapor Pressure   (mBars)   (kPa)
# Date
# 2020-03-31                                  3.675458
# 2020-06-30                                  4.524176
# 2020-09-30                                  5.227536
# 2020-12-31                                  3.989130

# %%
#caw_vapor_monthly_average.plot.bar()

# %%
# plt.title('Monthly Sum of Average Vapor Pressure, Pacific Grove')
# plt.grid(True)
# caw_plot = plt.plot(caw_vapor_monthly_sum.index, caw_vapor_monthly_sum['Average Vapor Pressure   (mBars)   (kPa)'],linewidth=3)

# %%
#  Average Vapor Pressure of Coalinga
caw_vapor_compare = caw_df_compare.iloc[:,[8]]
caw_vapor_compare
# Out:
#             Average Vapor Pressure   (mBars)   (kPa)
# Date
# 2020-01-01                                       7.1
# 2020-01-02                                       5.6
# 2020-01-03                                       4.9
# 2020-01-04                                       5.7
# 2020-01-05                                       5.1
# ...                                              ...
# 2020-12-27                                       4.2
# 2020-12-28                                       3.6
# 2020-12-29                                       3.4
# 2020-12-30                                       4.7
# 2020-12-31                                       4.4
#
# [366 rows x 1 columns]

# %%
print(type(caw_vapor_compare.index))
# Out:
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>

# %%
# Monthly and quarterly sum of Average Vapor Pressure, Coalinga
print("  Monthly Average Vapor Pressure, Coalinga")
caw_vapor_compare_monthly_average = caw_vapor_compare.resample('M').mean()
print(caw_vapor_compare_monthly_average)
print('-----------------------------------------------------')
print("  Quarterly Average Vapor Pressure, Coalinga")
caw_vapor_compare_quarter_average = caw_vapor_compare.resample('Q').mean()/3
print(caw_vapor_compare_quarter_average)
# Out:
#   Monthly Average Vapor Pressure, Coalinga
#             Average Vapor Pressure   (mBars)   (kPa)
# Date
# 2020-01-31                                  5.564516
# 2020-02-29                                  4.055172
# 2020-03-31                                  4.990323
# 2020-04-30                                  6.263333
# 2020-05-31                                  8.164516
# 2020-06-30                                 10.123333
# 2020-07-31                                 10.900000
# 2020-08-31                                 10.890323
# 2020-09-30                                  7.993333
# 2020-10-31                                  6.300000
# 2020-11-30                                  5.183333
# 2020-12-31                                  4.570968
# -----------------------------------------------------
#   Quarterly Average Vapor Pressure, Coalinga
#             Average Vapor Pressure   (mBars)   (kPa)
# Date
# 2020-03-31                                  1.629304
# 2020-06-30                                  2.727839
# 2020-09-30                                  3.316304
# 2020-12-31                                  1.784420

# %%
plt.plot(caw_vapor_monthly_average.index, caw_vapor_monthly_average['Average Vapor Pressure   (mBars)   (kPa)'],label='Pacific Grove',linewidth=3)
plt.plot(caw_vapor_compare_monthly_average.index, caw_vapor_compare_monthly_average['Average Vapor Pressure   (mBars)   (kPa)'],label='Coalinga',linewidth=3)
plt.title('Pacific Grove vs Coalinga: Monthly Average Vapor Pressure')
plt.ylabel('Average Vapor Pressure')
plt.xlabel('Month')
plt.grid()
plt.legend()

# %% [markdown]
# From the graph we can prove that our assumption is right.
# Each month, the sum of Avarage Vapor Pressure of Pacific Grove is about 300 kPa higher than that of Coalinga.
# We also noticed that the Avarage Vapor Pressure of Pacific Grove and Coalinga both reaches the peak during the summer.

# %% [markdown]
# ---

# %% [markdown]
# Compare the Average Wind Speed of the two places

# %%
# Average Wind Speed of Pacific Grove  
caw_wind = caw_df.iloc[:,[24]]
caw_wind
# Out:
#             Average Wind Speed   (mph)   (m/s)
# Date
# 2020-01-01                                 7.2
# 2020-01-02                                 4.8
# 2020-01-03                                 3.6
# 2020-01-04                                 5.8
# 2020-01-05                                 6.9
# ...                                        ...
# 2020-12-27                                 2.6
# 2020-12-28                                 3.0
# 2020-12-29                                 1.9
# 2020-12-30                                 1.9
# 2020-12-31                                 3.9
#
# [366 rows x 1 columns]

# %%
# Monthly and quarterly sum of Average Wind Speed, Pacific Grove
print("Monthly Average Wind Speed, Pacific Grove")
print()
caw_wind_monthly_average = caw_wind.resample('M').mean()
print(caw_wind_monthly_average)
print('-----------------------------------------------------')
print("Quarterly Average Wind Speed, Pacific Grove")
print()
caw_wind_quarter_average = caw_wind.resample('Q').mean()/3
print(caw_wind_quarter_average)
# Out:
# Monthly Average Wind Speed, Pacific Grove
#
#             Average Wind Speed   (mph)   (m/s)
# Date
# 2020-01-31                            4.496774
# 2020-02-29                            2.975862
# 2020-03-31                            2.964516
# 2020-04-30                            3.370000
# 2020-05-31                            3.270968
# 2020-06-30                            3.370000
# 2020-07-31                            3.116129
# 2020-08-31                            2.816129
# 2020-09-30                            2.373333
# 2020-10-31                            2.209677
# 2020-11-30                            2.633333
# 2020-12-31                            2.454839
# -----------------------------------------------------
# Quarterly Average Wind Speed, Pacific Grove
#
#             Average Wind Speed   (mph)   (m/s)
# Date
# 2020-03-31                            1.163370
# 2020-06-30                            1.112088
# 2020-09-30                            0.924275
# 2020-12-31                            0.810145

# %%
# Average Wind Speed of Coalinga 
caw_wind_compare = caw_df_compare.iloc[:,[24]]
caw_wind_compare
# Out:
#             Average Wind Speed   (mph)   (m/s)
# Date
# 2020-01-01                                 7.7
# 2020-01-02                                 3.3
# 2020-01-03                                 5.4
# 2020-01-04                                 6.2
# 2020-01-05                                 4.4
# ...                                        ...
# 2020-12-27                                 3.5
# 2020-12-28                                 5.1
# 2020-12-29                                 1.8
# 2020-12-30                                 5.7
# 2020-12-31                                 2.3
#
# [366 rows x 1 columns]

# %%
# Monthly and quarterly sum of Average Wind Speed, Coalinga
print(" Monthly Average Wind Speed, Coalinga")
print()
caw_wind_compare_monthly_average = caw_wind_compare.resample('M').mean()
print(caw_wind_compare_monthly_average)
print('-----------------------------------------------------')
print(" Quarterly Average Wind Speed, Coalinga")
print()
caw_wind_compare_quarter_average = caw_wind_compare.resample('Q').mean()/3
print(caw_wind_compare_quarter_average)
# Out:
#  Monthly Average Wind Speed, Coalinga
#
#             Average Wind Speed   (mph)   (m/s)
# Date
# 2020-01-31                            4.787097
# 2020-02-29                            4.158621
# 2020-03-31                            5.338710
# 2020-04-30                            5.946667
# 2020-05-31                            5.509677
# 2020-06-30                            5.443333
# 2020-07-31                            4.245161
# 2020-08-31                            4.212903
# 2020-09-30                            4.003333
# 2020-10-31                            3.735484
# 2020-11-30                            4.690000
# 2020-12-31                            3.590323
# -----------------------------------------------------
#  Quarterly Average Wind Speed, Coalinga
#
#             Average Wind Speed   (mph)   (m/s)
# Date
# 2020-03-31                            1.591575
# 2020-06-30                            1.877289
# 2020-09-30                            1.385145
# 2020-12-31                            1.332609

# %%
# plt.plot(caw_wind_monthly_sum.index, caw_wind_monthly_sum['Average Wind Speed   (mph)   (m/s)'],label='Pacific Grove',linewidth=3)
# plt.plot(caw_wind_compare_monthly_sum.index, caw_wind_compare_monthly_sum['Average Wind Speed   (mph)   (m/s)'],label='Coalinga',linewidth=3)
# plt.title('Pacific Grove vs Coalinga: Monthly Sum of Average Wind Speed')
# plt.ylabel('Average Wind Spped')
# plt.xlabel('Month')
# plt.grid()
# plt.legend()

# %%
fig = plt.figure()
plt.plot(caw_wind_monthly_average.index, caw_wind_monthly_average['Average Wind Speed   (mph)   (m/s)'],'ys-') 
plt.plot(caw_wind_compare_monthly_average.index, caw_wind_compare_monthly_average['Average Wind Speed   (mph)   (m/s)'],'go--')
plt.legend(labels = ('Pacific Grove', 'Coalinga'), loc = 'upper right') 
plt.title("Pacific Grove vs Coalinga: Monthly Average Wind Speed")
plt.xlabel('Month')
plt.ylabel('Average Wind Speed')
plt.grid()

# %%
caw_wind_monthly_average.plot.bar()
caw_wind_compare_monthly_average.plot.bar()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
caw_wind_quarter_average.plot.bar()
caw_wind_compare_quarter_average.plot.bar()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
caw_vapor_monthly_average.plot.bar()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
caw_vapor_compare_monthly_average.plot.bar()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
caw_vapor_compare_quarter_average.plot.bar()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
caw_vapor_quarter_average.plot.bar()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
caw_vapor.describe()
# Out:
#        Average Vapor Pressure   (mBars)   (kPa)
# count                                366.000000
# mean                                  13.066393
# std                                    2.592643
# min                                    4.700000
# 25%                                   11.000000
# 50%                                   13.350000
# 75%                                   15.275000
# max                                   20.300000

# %%
caw_vapor_compare.describe()
# Out:
#        Average Vapor Pressure   (mBars)   (kPa)
# count                                366.000000
# mean                                   7.096448
# std                                    2.890952
# min                                    2.200000
# 25%                                    4.700000
# 50%                                    6.450000
# 75%                                    9.200000
# max                                   14.700000

# %%
caw_wind.describe()
# Out:
#        Average Wind Speed   (mph)   (m/s)
# count                          366.000000
# mean                             3.005191
# std                              1.131807
# min                              1.300000
# 25%                              2.300000
# 50%                              2.700000
# 75%                              3.300000
# max                              8.100000

# %%
caw_wind_compare.describe()
# Out:
#        Average Wind Speed   (mph)   (m/s)
# count                          366.000000
# mean                             4.636885
# std                              1.948974
# min                              1.200000
# 25%                              3.200000
# 50%                              4.300000
# 75%                              5.700000
# max                             12.400000

# %% [markdown]
# The average of Vapor Pressure of Pacific Grove(13.1) is grater than that of Coalinga(7.1).
# The standard deviation of Vapor Pressure of Pacific Grove(2.6) is smaller than that of Coalinga(2.9).
# The average of Wind speed of Pacific Grove(3.0) is smaller than that of Coalinga(4.6).
# The standard deviation of Wind speed of Pacific Grove(1.1) is lower than that of Coalinga(1.9).
#
# Conculsion:
# 1.The average Vapor Pressure of coastal plain is greater than inland alpine.
# 2.The average Wind Speed of coastal plain is smaller than inland alpine.
# 3.The avarage Vapor Pressure of coastal plain and inland alpine both reaches the peak during the summer.
# 4.For both of coastal plain and inland alpine, the Wind Speed of first half of the year is greater than the last half of the year.
