# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("2020daily193.csv", index_col='Date',parse_dates=True)

# %%
pacific_df=pd.DataFrame(df)

# %%
df_compare=pd.read_csv("2020daily091.csv", index_col='Date',parse_dates=True)

# %%
coalinga_df=pd.DataFrame(df_compare)

# %%
pacific_df
# Out:
#             Station Id  Julian Date  Reference ETo   (in)   (mm)  \
# Date
# 2020-01-01         193            1                         0.02
# 2020-01-02         193            2                         0.06
# 2020-01-03         193            3                         0.06
# 2020-01-04         193            4                         0.05
# 2020-01-05         193            5                         0.06
# ...                ...          ...                          ...
# 2020-12-27         193          362                         0.06
# 2020-12-28         193          363                         0.05
# 2020-12-29         193          364                         0.06
# 2020-12-30         193          365                         0.05
# 2020-12-31         193          366                         0.06
#
#            QC for Reference ETo  Precipitation   (in)   (mm)  \
# Date
# 2020-01-01                                              0.00
# 2020-01-02                                              0.00
# 2020-01-03                                              0.00
# 2020-01-04                                              0.00
# 2020-01-05                                              0.00
# ...                         ...                          ...
# 2020-12-27                                              0.10
# 2020-12-28                                              0.10
# 2020-12-29                                              0.00
# 2020-12-30                                              0.02
# 2020-12-31                                              0.03
#
#            QC for Precipitation  Solar Radiation Average   (Ly/day)   (W/m≤)  \
# Date
# 2020-01-01                                                               131
# 2020-01-02                                                               264
# 2020-01-03                                                               275
# 2020-01-04                                                               218
# 2020-01-05                                                               277
# ...                         ...                                          ...
# 2020-12-27                                                               252
# 2020-12-28                                                               219
# 2020-12-29                                                               274
# 2020-12-30                                                               259
# 2020-12-31                                                               262
#
#            QC for Solar Radiation Average  \
# Date
# 2020-01-01
# 2020-01-02
# 2020-01-03
# 2020-01-04
# 2020-01-05
# ...                                   ...
# 2020-12-27
# 2020-12-28
# 2020-12-29
# 2020-12-30
# 2020-12-31
#
#             Average Vapor Pressure   (mBars)   (kPa)  \
# Date
# 2020-01-01                                      13.4
# 2020-01-02                                      12.8
# 2020-01-03                                      11.0
# 2020-01-04                                      12.8
# 2020-01-05                                      11.0
# ...                                              ...
# 2020-12-27                                      10.7
# 2020-12-28                                      10.6
# 2020-12-29                                       9.5
# 2020-12-30                                       9.8
# 2020-12-31                                      11.2
#
#            QC for Average Vapor Pressure   ...  \
# Date                                       ...
# 2020-01-01                                 ...
# 2020-01-02                                 ...
# 2020-01-03                                 ...
# 2020-01-04                                 ...
# 2020-01-05                                 ...
# ...                                   ...  ...
# 2020-12-27                                 ...
# 2020-12-28                                 ...
# 2020-12-29                                 ...
# 2020-12-30                                 ...
# 2020-12-31                                 ...
#
#            Average Relative Humidity   (%) QC for Average Relative Humidity  \
# Date
# 2020-01-01                              96
# 2020-01-02                              90
# 2020-01-03                              79
# 2020-01-04                              90
# 2020-01-05                              81
# ...                                    ...                              ...
# 2020-12-27                              86
# 2020-12-28                              85
# 2020-12-29                              80
# 2020-12-30                              86
# 2020-12-31                              86
#
#            Dew Point   (∞F)   (∞C) QC for Dew Point  \
# Date
# 2020-01-01                    52.3
# 2020-01-02                    51.1
# 2020-01-03                      47
# 2020-01-04                    51.2
# 2020-01-05                    47.1
# ...                            ...              ...
# 2020-12-27                    46.4
# 2020-12-28                    46.2
# 2020-12-29                    43.2
# 2020-12-30                    44.1
# 2020-12-31                    47.5
#
#            Average Wind Speed   (mph)   (m/s) QC for Average Wind Speed  \
# Date
# 2020-01-01                                7.2
# 2020-01-02                                4.8
# 2020-01-03                                3.6
# 2020-01-04                                5.8
# 2020-01-05                                6.9
# ...                                       ...                       ...
# 2020-12-27                                2.6
# 2020-12-28                                3.0
# 2020-12-29                                1.9
# 2020-12-30                                1.9
# 2020-12-31                                3.9
#
#            Wind Run   (miles)   (km) QC for Wind Run  \
# Date
# 2020-01-01                     173.1
# 2020-01-02                     114.7
# 2020-01-03                      85.4
# 2020-01-04                     139.1
# 2020-01-05                     164.6
# ...                              ...             ...
# 2020-12-27                      62.5
# 2020-12-28                      71.7
# 2020-12-29                      46.2
# 2020-12-30                      45.0
# 2020-12-31                      94.3
#
#            Average Soil Temperature   (∞F)   (∞C)  \
# Date
# 2020-01-01                                   55.6
# 2020-01-02                                   56.2
# 2020-01-03                                   56.0
# 2020-01-04                                   56.3
# 2020-01-05                                   56.4
# ...                                           ...
# 2020-12-27                                   55.5
# 2020-12-28                                   55.4
# 2020-12-29                                   55.1
# 2020-12-30                                   54.3
# 2020-12-31                                   54.8
#
#            QC for Average Soil Temperature
# Date
# 2020-01-01
# 2020-01-02
# 2020-01-03
# 2020-01-04
# 2020-01-05
# ...                                    ...
# 2020-12-27
# 2020-12-28
# 2020-12-29
# 2020-12-30
# 2020-12-31
#
# [366 rows x 30 columns]

# %%
coalinga_df
# Out:
#             Station Id  Julian Date  Reference ETo   (in)   (mm)  \
# Date
# 2020-01-01          91            1                         0.03
# 2020-01-02          91            2                         0.04
# 2020-01-03          91            3                         0.05
# 2020-01-04          91            4                         0.04
# 2020-01-05          91            5                         0.03
# ...                ...          ...                          ...
# 2020-12-27          91          362                         0.03
# 2020-12-28          91          363                         0.04
# 2020-12-29          91          364                         0.02
# 2020-12-30          91          365                         0.04
# 2020-12-31          91          366                         0.02
#
#            QC for Reference ETo  Precipitation   (in)   (mm)  \
# Date
# 2020-01-01                                              0.08
# 2020-01-02                                              0.00
# 2020-01-03                                              0.00
# 2020-01-04                                              0.08
# 2020-01-05                                              0.00
# ...                         ...                          ...
# 2020-12-27                                              0.00
# 2020-12-28                                              0.00
# 2020-12-29                                              0.00
# 2020-12-30                                              0.00
# 2020-12-31                                              0.20
#
#            QC for Precipitation  Solar Radiation Average   (Ly/day)   (W/m≤)  \
# Date
# 2020-01-01                                                               130
# 2020-01-02                                                               184
# 2020-01-03                                                               145
# 2020-01-04                                                               174
# 2020-01-05                                                               139
# ...                         ...                                          ...
# 2020-12-27                                                               142
# 2020-12-28                                                               213
# 2020-12-29                                                               178
# 2020-12-30                                                               132
# 2020-12-31                                                               109
#
#            QC for Solar Radiation Average  \
# Date
# 2020-01-01
# 2020-01-02
# 2020-01-03
# 2020-01-04
# 2020-01-05
# ...                                   ...
# 2020-12-27
# 2020-12-28
# 2020-12-29
# 2020-12-30
# 2020-12-31
#
#             Average Vapor Pressure   (mBars)   (kPa)  \
# Date
# 2020-01-01                                       7.1
# 2020-01-02                                       5.6
# 2020-01-03                                       4.9
# 2020-01-04                                       5.7
# 2020-01-05                                       5.1
# ...                                              ...
# 2020-12-27                                       4.2
# 2020-12-28                                       3.6
# 2020-12-29                                       3.4
# 2020-12-30                                       4.7
# 2020-12-31                                       4.4
#
#            QC for Average Vapor Pressure   ...  \
# Date                                       ...
# 2020-01-01                                 ...
# 2020-01-02                                 ...
# 2020-01-03                                 ...
# 2020-01-04                                 ...
# 2020-01-05                                 ...
# ...                                   ...  ...
# 2020-12-27                                 ...
# 2020-12-28                                 ...
# 2020-12-29                                 ...
# 2020-12-30                                 ...
# 2020-12-31                                 ...
#
#             Average Relative Humidity   (%) QC for Average Relative Humidity  \
# Date
# 2020-01-01                               84
# 2020-01-02                               79
# 2020-01-03                               64
# 2020-01-04                               76
# 2020-01-05                               87
# ...                                     ...                              ...
# 2020-12-27                               79
# 2020-12-28                               69
# 2020-12-29                               82
# 2020-12-30                               70
# 2020-12-31                               85
#
#             Dew Point   (∞F)   (∞C) QC for Dew Point  \
# Date
# 2020-01-01                     35.6
# 2020-01-02                     29.8
# 2020-01-03                     26.5
# 2020-01-04                     30.3
# 2020-01-05                     27.7
# ...                             ...              ...
# 2020-12-27                     23.0
# 2020-12-28                     19.5
# 2020-12-29                     18.1
# 2020-12-30                     25.6
# 2020-12-31                     24.1
#
#             Average Wind Speed   (mph)   (m/s) QC for Average Wind Speed  \
# Date
# 2020-01-01                                 7.7
# 2020-01-02                                 3.3
# 2020-01-03                                 5.4
# 2020-01-04                                 6.2
# 2020-01-05                                 4.4
# ...                                        ...                       ...
# 2020-12-27                                 3.5
# 2020-12-28                                 5.1
# 2020-12-29                                 1.8
# 2020-12-30                                 5.7
# 2020-12-31                                 2.3
#
#             Wind Run   (miles)   (km) QC for Wind Run  \
# Date
# 2020-01-01                      184.8
# 2020-01-02                       79.2
# 2020-01-03                      129.4
# 2020-01-04                      149.0
# 2020-01-05                      106.3
# ...                               ...             ...
# 2020-12-27                       85.2
# 2020-12-28                      121.7
# 2020-12-29                       42.7
# 2020-12-30                      135.8
# 2020-12-31                       54.5
#
#             Average Soil Temperature   (∞F)   (∞C)  \
# Date
# 2020-01-01                                    36.1
# 2020-01-02                                    36.8
# 2020-01-03                                    36.5
# 2020-01-04                                    36.9
# 2020-01-05                                    37.4
# ...                                            ...
# 2020-12-27                                    34.8
# 2020-12-28                                    34.6
# 2020-12-29                                    34.1
# 2020-12-30                                    34.0
# 2020-12-31                                    34.1
#
#            QC for Average Soil Temperature
# Date
# 2020-01-01
# 2020-01-02
# 2020-01-03
# 2020-01-04
# 2020-01-05
# ...                                    ...
# 2020-12-27
# 2020-12-28
# 2020-12-29
# 2020-12-30
# 2020-12-31
#
# [366 rows x 30 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## 1. Compare the Solar Radiation Average of the two places

# %% [markdown]
# ### Solar Radiation Average of Pacific Grove

# %%
pacific_solar = pacific_df.iloc[:,[6]]
pacific_solar
# Out:
#             Solar Radiation Average   (Ly/day)   (W/m≤)
# Date
# 2020-01-01                                          131
# 2020-01-02                                          264
# 2020-01-03                                          275
# 2020-01-04                                          218
# 2020-01-05                                          277
# ...                                                 ...
# 2020-12-27                                          252
# 2020-12-28                                          219
# 2020-12-29                                          274
# 2020-12-30                                          259
# 2020-12-31                                          262
#
# [366 rows x 1 columns]

# %%
# Monthly and quarterly Solar Radiation Average of pacific Grove 
print("   Monthly Solar Radiation Average, pacific Grove")
print()
pacific_solar_monthly_average = pacific_solar.resample('M').mean()
print(pacific_solar_monthly_average)
print('-----------------------------------------------------')
print("   Quarterly Solar Radiation Average, pacific Grove")
print()
print(pacific_solar.resample('Q').mean())
# Out:
#    Monthly Solar Radiation Average, pacific Grove
#
#             Solar Radiation Average   (Ly/day)   (W/m≤)
# Date
# 2020-01-31                                   240.548387
# 2020-02-29                                   343.172414
# 2020-03-31                                   384.967742
# 2020-04-30                                   476.833333
# 2020-05-31                                   615.290323
# 2020-06-30                                   562.700000
# 2020-07-31                                   472.516129
# 2020-08-31                                   421.580645
# 2020-09-30                                   364.333333
# 2020-10-31                                   332.806452
# 2020-11-30                                   292.766667
# 2020-12-31                                   235.225806
# -----------------------------------------------------
#    Quarterly Solar Radiation Average, pacific Grove
#
#             Solar Radiation Average   (Ly/day)   (W/m≤)
# Date
# 2020-03-31                                   322.450549
# 2020-06-30                                   552.307692
# 2020-09-30                                   420.076087
# 2020-12-31                                   286.869565

# %%
plt.title('Monthly Solar Radiation Average, pacific Grove')
plt.grid(True)
caw_plot = plt.plot(pacific_solar_monthly_average.index, pacific_solar_monthly_average['Solar Radiation Average   (Ly/day)   (W/m≤)'], linewidth=3)

# %% [markdown]
# ### Solar Radiation Average of Coalinga

# %%
coalinga_solar = coalinga_df.iloc[:,[6]]
coalinga_solar
# Out:
#             Solar Radiation Average   (Ly/day)   (W/m≤)
# Date
# 2020-01-01                                          130
# 2020-01-02                                          184
# 2020-01-03                                          145
# 2020-01-04                                          174
# 2020-01-05                                          139
# ...                                                 ...
# 2020-12-27                                          142
# 2020-12-28                                          213
# 2020-12-29                                          178
# 2020-12-30                                          132
# 2020-12-31                                          109
#
# [366 rows x 1 columns]

# %%
# Monthly and quarterly Solar Radiation Average of coalinga
print("      Monthly Solar Radiation Average, coalinga")
print()
coalinga_solar_monthly_average = coalinga_solar.resample('M').mean()
print(coalinga_solar_monthly_average)
print('-----------------------------------------------------')
print("      Quarterly Solar Radiation Average, coalinga")
print()
print(coalinga_solar.resample('Q').mean())
# Out:
#       Monthly Solar Radiation Average, coalinga
#
#             Solar Radiation Average   (Ly/day)   (W/m≤)
# Date
# 2020-01-31                                   146.354839
# 2020-02-29                                   298.724138
# 2020-03-31                                   344.290323
# 2020-04-30                                   507.966667
# 2020-05-31                                   557.612903
# 2020-06-30                                   640.966667
# 2020-07-31                                   678.967742
# 2020-08-31                                   542.709677
# 2020-09-30                                   465.066667
# 2020-10-31                                   355.419355
# 2020-11-30                                   210.866667
# 2020-12-31                                   162.483871
# -----------------------------------------------------
#       Quarterly Solar Radiation Average, coalinga
#
#             Solar Radiation Average   (Ly/day)   (W/m≤)
# Date
# 2020-03-31                                   262.340659
# 2020-06-30                                   568.725275
# 2020-09-30                                   563.304348
# 2020-12-31                                   243.271739

# %%
plt.title('Monthly Solar Radiation Average, coalinga')
plt.grid(True)
caw_plot = plt.plot(coalinga_solar_monthly_average.index, coalinga_solar_monthly_average['Solar Radiation Average   (Ly/day)   (W/m≤)'], linewidth=3)

# %%
plt.plot(pacific_solar_monthly_average.index, pacific_solar_monthly_average['Solar Radiation Average   (Ly/day)   (W/m≤)'],label='Pacific Grove',linewidth=3)
plt.plot(coalinga_solar_monthly_average.index, coalinga_solar_monthly_average['Solar Radiation Average   (Ly/day)   (W/m≤)'],label='Coalinga',linewidth=3)
plt.title('Pacific Grove vs coalinga: Solar Radiation Average')
plt.ylabel('Solar Radiation Average')
plt.grid()
plt.legend()

# %%
pacific_solar.std()
# Out:
# Solar Radiation Average   (Ly/day)   (W/m≤)    158.697281
# dtype: float64

# %%
coalinga_solar.std()
# Out:
# Solar Radiation Average   (Ly/day)   (W/m≤)    201.125014
# dtype: float64

# %% [markdown]
# ### Conclusion
# **From the graph we can see that:**
# - Pacific Grove has the highest Solar Radiation Average in the second quarter, while the Solar Radiation Average of Coalinga reaches its peak in the third quarter.
# - Coalinga(201.13) has a larger standard deviation than Pacific Grove(158.70) in terms of Solar Radiation Average.
# - Generally speaking, from April to the end of October, the Solar Radiation Average of Coalinga becomes higher than that of Pacific Grove.

# %% [markdown]
# ---

# %% [markdown]
# ## Compare the Maximum Air Temperature of the two places

# %% [markdown]
# **Before jumping into actual analysis, we made an assumption based on the knowledge that coastal areas generally have more moderate temperatures than inland interiors. We expect to see that Pacific Grove will have a smaller standard deviation in terms of Maximum Air Temperature.**

# %% [markdown]
# ### Maximum Air Temperature of Pacific Grove

# %%
pacific_df['Maximum Air Temperature   (∞F)   (∞C)'].replace('--', "NaN", inplace=True)
pacific_df['Maximum Air Temperature   (∞F)   (∞C)'] = pacific_df['Maximum Air Temperature   (∞F)   (∞C)'].astype(float)
pacific_temp_max = pacific_df.iloc[:,[10]]
pacific_temp_max
# Out:
#             Maximum Air Temperature   (∞F)   (∞C)
# Date
# 2020-01-01                                   57.1
# 2020-01-02                                   59.8
# 2020-01-03                                   62.4
# 2020-01-04                                   57.3
# 2020-01-05                                   58.1
# ...                                           ...
# 2020-12-27                                   56.3
# 2020-12-28                                   57.3
# 2020-12-29                                   58.0
# 2020-12-30                                   53.3
# 2020-12-31                                   55.2
#
# [366 rows x 1 columns]

# %%
# Monthly and quarterly average of Average Vapor Pressure, pacific Grove
print("Monthly Sum of Maximum Air Temperature, Pacific Grove")
print()
pacific_temp_max_monthly_average = pacific_temp_max.resample('M').mean()
print(pacific_temp_max_monthly_average)
print('-----------------------------------------------------')
print("Quarterly Sum of Average Vapor Pressure, Pacific Grove")
print()
print(pacific_temp_max.resample('Q').mean())
# Out:
# Monthly Sum of Maximum Air Temperature, Pacific Grove
#
#             Maximum Air Temperature   (∞F)   (∞C)
# Date
# 2020-01-31                              57.832258
# 2020-02-29                              58.472414
# 2020-03-31                              58.400000
# 2020-04-30                              58.813333
# 2020-05-31                              61.453333
# 2020-06-30                              61.416667
# 2020-07-31                              61.341935
# 2020-08-31                              62.919355
# 2020-09-30                              62.316667
# 2020-10-31                              64.264516
# 2020-11-30                              60.930000
# 2020-12-31                              58.270968
# -----------------------------------------------------
# Quarterly Sum of Average Vapor Pressure, Pacific Grove
#
#             Maximum Air Temperature   (∞F)   (∞C)
# Date
# 2020-03-31                              58.229670
# 2020-06-30                              60.561111
# 2020-09-30                              62.191304
# 2020-12-31                              61.157609

# %% [markdown]
# ### Maximum Air Temperature of Coalinga

# %%
coalinga_df['Maximum Air Temperature   (∞F)   (∞C)'].replace('--', "NaN", inplace=True)
coalinga_df['Maximum Air Temperature   (∞F)   (∞C)'] = coalinga_df['Maximum Air Temperature   (∞F)   (∞C)'].astype(float)
coalinga_temp_max = coalinga_df.iloc[:,[10]]
coalinga_temp_max
# Out:
#             Maximum Air Temperature   (∞F)   (∞C)
# Date
# 2020-01-01                                   48.4
# 2020-01-02                                   46.5
# 2020-01-03                                   55.4
# 2020-01-04                                   43.6
# 2020-01-05                                   41.7
# ...                                           ...
# 2020-12-27                                   39.8
# 2020-12-28                                   38.9
# 2020-12-29                                   36.3
# 2020-12-30                                   47.3
# 2020-12-31                                   36.3
#
# [366 rows x 1 columns]

# %%
# Monthly and quarterly average of Maximum Air Temperature, coalinga
print("Monthly Sum of Maximum Air Temperature, Coalinga")
print()
coalinga_temp_max_monthly_average = coalinga_temp_max.resample('M').mean()
print(coalinga_temp_max_monthly_average)
print('-----------------------------------------------------')
print("Quarterly Sum of Average Vapor Pressure, Pacific Grove")
print()
print(coalinga_temp_max.resample('Q').mean())
# Out:
# Monthly Sum of Maximum Air Temperature, Coalinga
#
#             Maximum Air Temperature   (∞F)   (∞C)
# Date
# 2020-01-31                              43.635484
# 2020-02-29                              51.165517
# 2020-03-31                              51.745161
# 2020-04-30                              61.770000
# 2020-05-31                              67.819355
# 2020-06-30                              73.886667
# 2020-07-31                              83.803226
# 2020-08-31                              85.429032
# 2020-09-30                              81.966667
# 2020-10-31                              69.651613
# 2020-11-30                              49.516667
# 2020-12-31                              42.874194
# -----------------------------------------------------
# Quarterly Sum of Average Vapor Pressure, Pacific Grove
#
#             Maximum Air Temperature   (∞F)   (∞C)
# Date
# 2020-03-31                              48.797802
# 2020-06-30                              67.825275
# 2020-09-30                              83.752174
# 2020-12-31                              54.063043

# %%
plt.plot(pacific_temp_max_monthly_average.index, pacific_temp_max_monthly_average['Maximum Air Temperature   (∞F)   (∞C)'],label='pacific',linewidth=3)
plt.plot(coalinga_temp_max_monthly_average.index, coalinga_temp_max_monthly_average['Maximum Air Temperature   (∞F)   (∞C)'],label='coalinga',linewidth=3)
plt.title('pacific Grove vs coalinga: Monthly Average of Maximum Air Temperature')
plt.ylabel('Maximum Air Temperature')
plt.grid()
plt.legend()

# %%
pacific_temp_max.std()
# Out:
# Maximum Air Temperature   (∞F)   (∞C)    4.377039
# dtype: float64

# %%
coalinga_temp_max.std()
# Out:
# Maximum Air Temperature   (∞F)   (∞C)    17.16106
# dtype: float64

# %% [markdown]
# ### Conclusion
# From the graph we can see, Pacific Grove displays a much more smooth line than Coalinga, indicating its standard deviation(4.38) is much lower than that of Coalinga(17.16) in terms of Maximum Air Temperature.
#
# Why so? **Heat Capacity** is the answer.
#
# Heat Capacity is a physical property of matter. It is the amount of energy needed to change the temperature of any material. Different matters have different heat capacity. The heat capacity of water (4.184 J/g °C) is 4-5 times higher than rock or dirt.
#
# As we know, Pacific Grove is surrounded by water, which takes much longer to heat and to cool than the land. But once the water is heated up or has collected enough heat, it retains its heat for a longer time than the inland area does.
#
# Therefore, it supports our conclusion that Pacific Grove has more moderate temperatures than Coalinga.

# %% [markdown]
# ---

# %% [markdown]
# ## Average Soil Temperature of the two places
#
# Now we want to do some analysis regarding the Average Soil Temperature. Instead of comparing the Average Soil Temperature of two places, we want to discover if there is a correlation between the Maximum Air Temperature and the Average Soil Temperature of each place.
#
# Again, we made a prior assumption that the higher the Maximum Air Temperature is, the higher Average Soil Temperature will be.

# %% [markdown]
# ### Average Soil Temperature of Pacific Grove

# %%
pacific_soil = pacific_df.iloc[:,[28]]
pacific_soil
# Out:
#             Average Soil Temperature   (∞F)   (∞C)
# Date
# 2020-01-01                                    55.6
# 2020-01-02                                    56.2
# 2020-01-03                                    56.0
# 2020-01-04                                    56.3
# 2020-01-05                                    56.4
# ...                                            ...
# 2020-12-27                                    55.5
# 2020-12-28                                    55.4
# 2020-12-29                                    55.1
# 2020-12-30                                    54.3
# 2020-12-31                                    54.8
#
# [366 rows x 1 columns]

# %%
# Monthly and quarterly Average Soil Temperature of pacific Grove 
print("   Monthly Average Soil Temperature, Pacific Grove")
print()
pacific_soil_monthly_average= pacific_soil.resample('M').mean()
print(pacific_soil_monthly_average)
print('-----------------------------------------------------')
print("   Quarterly Average Soil Temperature, Pacific Grove")
print()
print(pacific_soil.resample('Q').mean())
# Out:
#    Monthly Average Soil Temperature, Pacific Grove
#
#             Average Soil Temperature   (∞F)   (∞C)
# Date
# 2020-01-31                               55.309677
# 2020-02-29                               55.572414
# 2020-03-31                               57.290323
# 2020-04-30                               60.086667
# 2020-05-31                               63.741935
# 2020-06-30                               64.343333
# 2020-07-31                               63.974194
# 2020-08-31                               65.377419
# 2020-09-30                               64.736667
# 2020-10-31                               62.748387
# 2020-11-30                               58.010000
# 2020-12-31                               55.248387
# -----------------------------------------------------
#    Quarterly Average Soil Temperature, Pacific Grove
#
#             Average Soil Temperature   (∞F)   (∞C)
# Date
# 2020-03-31                               56.068132
# 2020-06-30                               62.735165
# 2020-09-30                               64.695652
# 2020-12-31                               58.676087

# %% [markdown]
# ### Average Soil Temperature of Coalinga

# %%
coalinga_soil = coalinga_df.iloc[:,[28]]
coalinga_soil
# Out:
#             Average Soil Temperature   (∞F)   (∞C)
# Date
# 2020-01-01                                    36.1
# 2020-01-02                                    36.8
# 2020-01-03                                    36.5
# 2020-01-04                                    36.9
# 2020-01-05                                    37.4
# ...                                            ...
# 2020-12-27                                    34.8
# 2020-12-28                                    34.6
# 2020-12-29                                    34.1
# 2020-12-30                                    34.0
# 2020-12-31                                    34.1
#
# [366 rows x 1 columns]

# %%
# Monthly and quarterly Average Soil Temperature of coalinga 
print("   Monthly Average Soil Temperature, Coalinga")
print()
coalinga_soil_monthly_average = coalinga_soil.resample('M').mean()
print(coalinga_soil_monthly_average)
print('-----------------------------------------------------')
print("   Quarterly Average Soil Temperature, Coalinga")
print()
print(coalinga_soil.resample('Q').mean())
# Out:
#    Monthly Average Soil Temperature, Coalinga
#
#             Average Soil Temperature   (∞F)   (∞C)
# Date
# 2020-01-31                               37.074194
# 2020-02-29                               36.686207
# 2020-03-31                               40.454839
# 2020-04-30                               49.046667
# 2020-05-31                               56.974194
# 2020-06-30                               64.623333
# 2020-07-31                               69.780645
# 2020-08-31                               69.480645
# 2020-09-30                               62.373333
# 2020-10-31                               53.358065
# 2020-11-30                               42.886667
# 2020-12-31                               35.251613
# -----------------------------------------------------
#    Quarterly Average Soil Temperature, Coalinga
#
#             Average Soil Temperature   (∞F)   (∞C)
# Date
# 2020-03-31                               38.102198
# 2020-06-30                               56.882418
# 2020-09-30                               67.264130
# 2020-12-31                               43.842391

# %%
fig = plt.figure()
plt.plot(pacific_temp_max_monthly_average.index, pacific_temp_max_monthly_average['Maximum Air Temperature   (∞F)   (∞C)'],'ys-') 
plt.plot(pacific_soil_monthly_average.index, pacific_soil_monthly_average['Average Soil Temperature   (∞F)   (∞C)'],'go--')
plt.legend(labels = ('Air Temperature', 'Soil Temperature'), loc = 'upper left') 
plt.title("pacific Grove: Correlation between Maximum Air Temperature and Average Soil Temperature")
plt.xlabel('Month')
plt.ylabel('Temperature (∞F) (∞C)')
plt.grid()

fig = plt.figure()
plt.plot(coalinga_temp_max_monthly_average.index, coalinga_temp_max_monthly_average['Maximum Air Temperature   (∞F)   (∞C)'],'ys-') 
plt.plot(coalinga_soil_monthly_average.index, coalinga_soil_monthly_average['Average Soil Temperature   (∞F)   (∞C)'],'go--')
plt.legend(labels = ('Air Temperature', 'Soil Temperature'), loc = 'upper left') 
plt.title("coalinga: Correlation between Maximum Air Temperature and Average Soil Temperature")
plt.xlabel('Month')
plt.ylabel('Temperature (∞F) (∞C)')
plt.grid()

# %% [markdown]
# ### Conclusion
# **From the two graphs above, we can conclude that:**
# - Compared with Pacific Grove, coalinga shows a better correlation between its Maximum Air Temperature and Average Soil Temperature.
# - However, generally speaking, the Average Soil Temperature of the two regions is proportional to their corresponding Maximum Air Temperature.
